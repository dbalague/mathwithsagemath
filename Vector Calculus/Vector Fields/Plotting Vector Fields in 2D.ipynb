# %% [markdown]
# # Example 1

# %% [markdown]
# In $\mathbb{R}^2$, the vector field $F(x,y)=\langle 1, 0\rangle$ assigns to each vector in the plane the horizontal vector $\langle 1,0\rangle$.

# %%
F(x,y) = [1,0]

# %%
plot_vector_field(F,(x,-3,3),(y,-3,3),aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Example 2

# %%
F(x,y) = [x, x^2]

# %%
plot_vector_field(F,(x,-2,2),(y,-2,2),aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive
